# %% [markdown]
# <h2>Array types and conversions between types</h2>

# %% [markdown]
# NumPy supports a much greater variety of numerical types than Python does.
# NumPy numerical types are instances of numpy.dtype (data-type) objects, each having unique characteristics.

# %%
import numpy as np

# %%
z = np.arange(3, dtype = np.uint8)
z
# Out:
# array([0, 1, 2], dtype=uint8)

# %% [markdown]
# Array types can also be referred to by character codes, for example:

# %%
np.array([1, 2, 3], dtype='f')
# Out:
# array([1., 2., 3.], dtype=float32)

# %%
np.array([1, 2, 3], dtype='d')
# Out:
# array([1., 2., 3.])

# %%
z.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# The data type can also be used indirectly to query properties of the type, such as whether it is an integer:

# %%
d = np.dtype(np.int64)
d
# Out:
# dtype('int64')

# %%
np.issubdtype(d, np.integer)
# Out:
# True

# %%
np.issubdtype(d, np.floating)
# Out:
# False
